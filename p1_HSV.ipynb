# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import time

# %%
# use OpenCV to read dimensional values of image
img_HSV = cv2.imread("wolves.png", cv2.IMREAD_UNCHANGED)
img = cv2.cvtColor(img_HSV, cv2.COLOR_BGR2HSV)
# cv2.imshow("image", img)
# cv2.waitKey(0)
print('Shape: ', img.shape)
print('Size: ', img.size)
# Out:
# Shape:  (539, 1500, 3)
# Size:  2425500

# %%
# size of image matrix
y_axis = len(img)
x_axis = len(img[0])
z_axis = len(img[0][0])
HSV_diff1 = []
HSV_diff2 = []
HSV_diff3 = []
start = np.zeros(6)
end = np.zeros(6)

# %%
start[0] = time.time()
for i in range(y_axis-1):
    for j in range(x_axis):
        sum_diff = 0
        for k in range(z_axis):
            sum_diff += (img[i][j][k] - img[i+1][j][k])**2
        HSV_diff1.append(sum_diff)
end[0] = time.time()
# Out:
# c:\Users\gaoyz\anaconda3\envs\ece558\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in ubyte_scalars

# %%
start[1] = time.time()
for i in range(y_axis):
    for j in range(x_axis-1):
        sum_diff = 0
        for k in range(z_axis):
            sum_diff += (img[i][j][k] - img[i][j+1][k])**2
        HSV_diff2.append(sum_diff)
end[1] = time.time()
# Out:
# c:\Users\gaoyz\anaconda3\envs\ece558\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in ubyte_scalars

# %%
start[2] = time.time()
for i in range(y_axis-1):
    for j in range(x_axis-1):
        sum_diff = 0
        for k in range(z_axis):
            sum_diff += (img[i][j][k] - img[i+1][j+1][k])**2
        HSV_diff3.append(sum_diff)
end[2] = time.time()
# Out:
# c:\Users\gaoyz\anaconda3\envs\ece558\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: overflow encountered in ubyte_scalars

# %%
start[3] = time.time()
plt.hist(HSV_diff1, 50, label="(x,y+1)")
plt.title("HSV pair (x,y) & (x,y+1)")
end[3] = time.time()

# %%
start[4] = time.time()
plt.hist(HSV_diff2, 50, label="(x+1,y)")
plt.title("HSV pair (x,y) & (x+1,y)")
end[4] = time.time()

# %%
start[5] = time.time()
plt.hist(HSV_diff3, 50, label="(x+1,y+1)")
plt.title("HSV pair (x,y) & (x+1,y+1)")
end[5] = time.time()

# %%
tot_time = sum(end) - sum(start)
print("Total runtime is", tot_time, "seconds.")
# Out:
# Total runtime is 20.65558433532715 seconds.
